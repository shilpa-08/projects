# %% [markdown]
# DATA DESCRIPTION
#
# Happiness Score Dataset it a dataset which shows the score of 158 coutries .The happiness score is rated after taking 7 factors in account
# Happines score is a continuous value which ranges from 1 to 10.it is a Regression type of problem.

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Loading Dataset

# %%
df=pd.read_csv('happiness_record_dataset.csv')

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %% [markdown]
# ### Analyzing Dataset

# %%
df.shape
# Out:
# (158, 12)

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
#
#     Country Name and Region are just for the information about the rows
#     they have actually nothing to do with the happiness rank
#     so we can drop them

# %%
#df.drop('Country','Regions','Happiness')

# %% [markdown]
# Observations:
#
#     1) As there is not remarkable difference between 75% value and max value it means there are no outliers
#
#     2) As mean and standard deviation are far from each other means data is skewed
#
#     3) By observing the min and max it can be predicted that there is no need to do standard scaling

# %%
# check null values in dataset
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# Observation : No Null Values are present

# %%
dfcor=df.corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(dfcor,cmap='YlOrRd_r',annot=True)

# %% [markdown]
#     Observation:
#         1) As Happiness Rank is rank of coutries from 1 to 158 that's why it is negatively correlated ,
#
#         2)family , life Expectancy, Trust Government are highly correlated
#
#         3)Standard Error  and Happiness score are negatively correlated

# %%
#Univariate Analysis
df['Happiness Score'].plot.hist()

# %%
#bivariate analysis
plt.scatter(df['Happiness Score'],df['Standard Error'])
plt.xlabel('Happiness Score')
plt.ylabel('Standard Error')
plt.show()

# %%
#Checkig Outlers
df.plot(kind='box',subplots=True,layout=(2,5),figsize=(18,12))
# Out:
# Happiness Rank                      AxesSubplot(0.125,0.536818;0.133621x0.343182)
# Happiness Score                  AxesSubplot(0.285345,0.536818;0.133621x0.343182)
# Standard Error                    AxesSubplot(0.44569,0.536818;0.133621x0.343182)
# Economy (GDP per Capita)         AxesSubplot(0.606034,0.536818;0.133621x0.343182)
# Family                           AxesSubplot(0.766379,0.536818;0.133621x0.343182)
# Health (Life Expectancy)               AxesSubplot(0.125,0.125;0.133621x0.343182)
# Freedom                             AxesSubplot(0.285345,0.125;0.133621x0.343182)
# Trust (Government Corruption)        AxesSubplot(0.44569,0.125;0.133621x0.343182)
# Generosity                          AxesSubplot(0.606034,0.125;0.133621x0.343182)
# Dystopia Residual                   AxesSubplot(0.766379,0.125;0.133621x0.343182)
# dtype: object

# %% [markdown]
# Observation : standard Error and Trust Government Corruption are having high amount of Outliers

# %% [markdown]
# ### Treating Outliers

# %% [markdown]
# for Treating Outliers as zscore do  not take string values so we can either do label encoding of Country and Region
# or we can drop them
#
# As for calculating happiness Score country name and Region have no important role
#
# so I will go for dropping these both columns

# %%
df.drop('Country',inplace=True,axis=1)
df.drop('Region',inplace=True,axis=1)

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.72099989, 1.93736005, 0.80592569, ..., 2.30965159, 0.47103971,
#         0.75825809],
#        [1.69907456, 1.91458063, 0.05588945, ..., 0.01647953, 1.57585637,
#         1.09285682],
#        [1.67714922, 1.88479215, 0.8544869 , ..., 2.8427738 , 0.8242928 ,
#         0.71233526],
#        ...,
#        [1.67742676, 2.0761992 , 0.13253425, ..., 0.38141902, 1.85689094,
#         3.20843049],
#        [1.69935209, 2.1646885 , 2.26396166, ..., 0.35771452, 0.31694987,
#         0.48198451],
#        [1.72127743, 2.22251319, 1.13418227, ..., 0.30180313, 0.5581534 ,
#         0.96361241]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([7, 2, 2, 2, 8, 4, 7, 9, 4], dtype=int64))

# %% [markdown]
# Observation:
#
# as number of Outliers are remarlably less, so I will
# leave the Outliers as it is and go without removing them as it leads to loss of data

# %%
# Checking skewness
for i in df.columns:
    plt.figure()
    sns.distplot(df[i])

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# As the skew score is less than +- 5 so no need to remove skewness

# %% [markdown]
# ### Separating Independent Variable and Dependent Variable

# %%
df.columns
# Out:
# Index(['Happiness Rank', 'Happiness Score', 'Standard Error',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
x=df.iloc[:,2:]
x.head()
# Out:
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
y=df.iloc[:,1]
y.head()
y.shape
# Out:
# (158,)

# %%
#Finding the best Random State
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from  sklearn.metrics import r2_score

# %%
maxaccuracy=0
maxrandomstate=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    lr.score(x_train,y_train)
    pred=lr.predict(x_test)
    r2score=r2_score(y_test,pred)
    if r2score > maxaccuracy:
        maxaccuracy=r2score
        maxrandomstate=i
print("Max r2_score is ",maxaccuracy,"best random state is ",maxrandomstate)
# Out:
# Max r2_score is  0.9999999650671216 best random state is  72

# %%
#Creating the Train_Test_Split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=i)    
lr=LinearRegression()
lr.fit(x_train,y_train)
lr.score(x_train,y_train)
predr=lr.predict(x_test)
print('r2_score is : ',r2_score(y_test,predr))
# Out:
# r2_score is :  0.9999999263195988

# %%
from sklearn.ensemble import RandomForestRegressor

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=72)    
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred=rf.predict(x_test)
print('r2_score is : ',r2_score(y_test,pred))
# Out:
# r2_score is :  0.9330286081517936

# %%
from sklearn.tree import DecisionTreeRegressor

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=72)    
dt=DecisionTreeRegressor()
dt.fit(x_train,y_train)
dt.score(x_train,y_train)
pred=dt.predict(x_test)
print('r2_score is : ',r2_score(y_test,pred))
# Out:
# r2_score is :  0.9022517867135439

# %%
from sklearn.svm import SVR

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=72)    
sv=SVR()
sv.fit(x_train,y_train)
sv.score(x_train,y_train)
pred=sv.predict(x_test)
print('r2_score is : ',r2_score(y_test,pred))
# Out:
# r2_score is :  0.9908112167175974

# %% [markdown]
# we are getting highest accuracy with Linear Regression

# %%
from sklearn.model_selection  import cross_val_score
scr=cross_val_score(lr,x,y,cv=5)
print("Cross Validation Score of Linear Regression model is :",scr.mean())
print("\n\n")
scr=cross_val_score(rf,x,y,cv=5)
print("Cross Validation Score of RandomForest Regressor model is :",scr.mean())
print("\n\n")
scr=cross_val_score(dt,x,y,cv=5)
print("Cross Validation Score of DecisionTree Regressor model is :",scr.mean())
print("\n\n")
scr=cross_val_score(sv,x,y,cv=5)
print("Cross Validation Score of Support Vector Regressor model is :",scr.mean())
print("\n\n")
# Out:
# Cross Validation Score of Linear Regression model is : 0.9999981871007761
#
#
#
# Cross Validation Score of RandomForest Regressor model is : -3.060439819190854
#
#
#
# Cross Validation Score of DecisionTree Regressor model is : -6.795356254263166
#
#
#
# Cross Validation Score of Support Vector Regressor model is : 0.028707305604232625

# %%
'''

           MODEL                R2_SCORE                CROSS VAL SCORE                 DIFFERENCE

            Linear                99                         0.99                             0
            RandomForest          92                         -3.0                            89
            DecisionTree          87                         -7.0                            80
            Support Vector        99                          0.02                           97



'''
# Out:
# '\n\n           MODEL                R2_SCORE                CROSS VAL SCORE                 DIFFERENCE\n\n            Linear                99                         0.99                             0\n            RandomForest          92                         -3.0                            89\n            DecisionTree          87                         -7.0                            80\n            Support Vector        99                          0.02                           97\n\n\n\n'

# %% [markdown]
# as there is no difference in Linear Model is Linear Regression seems to be properly trained

# %%
#Creating the Train_Test_Split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=i)    
lr=LinearRegression()
lr.fit(x_train,y_train)
lr.score(x_train,y_train)
predr=lr.predict(x_test)
print('r2_score is : ',r2_score(y_test,predr))
# Out:
# r2_score is :  0.9999999263195988

# %%
lr.coef_
# Out:
# array([-2.35314610e-04,  1.00008730e+00,  1.00006176e+00,  9.99779372e-01,
#         9.99769893e-01,  9.99907176e-01,  1.00007998e+00,  1.00003863e+00])

# %% [markdown]
# there can be a posiiblity of High Biasness or High Variance so we need to Regularize the model

# %%
from sklearn.linear_model import Lasso,Ridge,ElasticNet

ls=Lasso(alpha=0.0001)

ls.fit(x_train,y_train)
ls.score(x_train,y_train)
# Out:
# 0.9999990341889703

# %%
rd=Ridge(alpha=0.0001)

rd.fit(x_train,y_train)
print(rd.score(x_train,y_train))
rd.coef_
# Out:
# 0.9999999443296251
# array([-3.47408302e-04,  1.00009995e+00,  1.00005256e+00,  9.99763100e-01,
#         9.99774231e-01,  9.99852267e-01,  1.00004210e+00,  1.00003469e+00])

# %% [markdown]
# AS linearv regression is the best model in this case ,but there is no externel parameter to be passed
# so no need to do Hyperparameter tuning

# %% [markdown]
# #### Exporting the Model

# %%
import joblib
joblib.dump(lr,'happiness_score_linear.pkl')
# Out:
# ['happiness_score_linear.pkl']
