# %% [markdown]
# ###  About Dataset

# %% [markdown]
# The BaseBall_Case_Studies is a dataset containing data from 2014 Major League Baseball seasons in order to develop an algorithm
# that predicts the number of wins for a given team in the 2015 season based on several different indicators of success.
# There are 16 different attributes in a dataset as the inputs to the machine learning and
# we have to make the model to predict the  output that represents the number of wins.

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Loading the Data

# %%
df=pd.read_csv('baseball.csv')

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# only ERA( Earned Run Average ) is in float other inputs are in int format

# %%
df.shape               # no of rows and columns
# Out:
# (30, 17)

# %% [markdown]
# ###  Checking for null values

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# there are no null values in the dataset

# %% [markdown]
# ###  Visualizing Data

# %%
# importing necessary libraries 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.distplot(df['W'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='Density'>

# %% [markdown]
# the Number of Wins data is normally distributed there is no skewness present

# %%
sns.distplot(df['R'])
# Out:
# <AxesSubplot:xlabel='R', ylabel='Density'>

# %% [markdown]
# 'R' - Runs data is also normally distributed there is no skewness

# %%
sns.distplot(df['E'])
# Out:
# <AxesSubplot:xlabel='E', ylabel='Density'>

# %% [markdown]
# E- Errors are also not skewed

# %%
# bivariate analysis
# let see the relation through scatterplot between two variables
sns.scatterplot(df['W'],df['R'])
plt.xlabel('No of Wins')
plt.ylabel('Runs')
plt.show()

# %% [markdown]
# the highest run of 900 is near 92 and other wins have run around 550 and 750

# %%
sns.scatterplot(df['W'],df['AB'])
plt.xlabel('No of Wins')
plt.ylabel('At Bats')
plt.show()

# %%
sns.scatterplot(df['W'],df['2B'])
plt.xlabel('No of Wins')
plt.ylabel('Doubles')
plt.show()

# %% [markdown]
# the highest Doubles Run is at 310 near a win of 92 or 93 and other wins  are al over between 230 to 300

# %%
sns.scatterplot(df['W'],df['3B'])
plt.xlabel('No of Wins')
plt.ylabel('Triples')
plt.show()

# %% [markdown]
# the highest number of wins 100 is at triples of 40 , and highest triples 50 has a win of 70

# %%
sns.scatterplot(df['W'],df['H'])
plt.xlabel('No of Wins')
plt.ylabel('Homeruns')
plt.show()

# %% [markdown]
# highest Homeruns are recorded near a win of 74-75  and highest wins of 100 are recorded at a homeruns of 1375

# %%
sns.scatterplot(df['W'],df['BB'])
plt.xlabel('No of Wins')
plt.ylabel('Walks')
plt.show()

# %% [markdown]
# the data shows somewhere a positive relationship, at the highest walks of 575 the number of Wins are 95

# %%
sns.scatterplot(df['W'],df['SO'])
plt.xlabel('No of Wins')
plt.ylabel('StrikeOuts')
plt.show()

# %% [markdown]
# the lowest strikeout below 1000 and highest strikeout above 1500 is at a win of 95

# %%
sns.scatterplot(df['W'],df['SB'])
plt.xlabel('No of Wins')
plt.ylabel('Stolen Bases')
plt.show()

# %% [markdown]
# the highest stolen base is at win of 65 i.e., 120 +

# %%
sns.scatterplot(df['W'],df['RA'])
plt.xlabel('No of Wins')
plt.ylabel('Runs Allowed')
plt.show()

# %% [markdown]
# Runs allowed is showing a negative linear relationship i.e., at runs of 850 the Wins is 65 and at runs of 550 the wins is 100

# %%
sns.scatterplot(df['W'],df['ER'])
plt.xlabel('No of Wins')
plt.ylabel(' Earned Runs')
plt.show()

# %% [markdown]
# Earned Run is also showing negative relation just like allowed runs

# %%
sns.scatterplot(df['W'],df['ERA'])
plt.xlabel('No of Wins')
plt.ylabel(' Earned Run Average')
plt.show()

# %% [markdown]
# Earned Runs Average is also showing negative linear relation i.e., at highest run average of 5.0 the Wins is 65 and at lowest Run Average of 3.0 the highest Wins is 100

# %%
sns.scatterplot(df['W'],df['SHO'])
plt.xlabel('No of Wins')
plt.ylabel('Shutouts')
plt.show()

# %% [markdown]
# Shutouts is showing positive linear relation somewhere like at lowest shutout of 5.0 the wins is lowest around 7.0 and at highest shutouts of 20.0+ the wins is of 97

# %%
sns.scatterplot(df['W'],df['SV'])
plt.xlabel('No of Wins')
plt.ylabel('Saves')
plt.show()

# %% [markdown]
# Saves is showing positive linear relation at lowest saves is the number od Wins are less and at Highest saves of 60 plus the no of wins are highest 100

# %%
sns.scatterplot(df['W'],df['E'])
plt.xlabel('No of Wins')
plt.ylabel('Errors')
plt.show()

# %% [markdown]
# the data of Error is having not defined relation , but at highest error of 120 plus the no of wins of 70

# %% [markdown]
# ### statistical analysis

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# #observations
#
# there is a  remarkable difference in 75% and max of HR, RA, CG indicating presence of outliers

# %% [markdown]
# ### Checking Correlation

# %%
dfcor=df.corr()

# %%
#plotting correlation
plt.figure(figsize=(22,8))
sns.heatmap(dfcor,cmap='YlOrRd_r',annot =True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observations :-
#
# 1) No of Wins is highly corelated with SV(saves), then with BB() ,then SHO(shutouts),
#
# 2) Wins is equally correlated with R(runs) and 2D(Doubles)
#
# 3) and it is  strongly negatively correlated with RA( runs allowed), ER (Earned runs), ERA(earned runs avearge)

# %% [markdown]
# ### Checking Outliers

# %%
collist=df.columns.values
ncol=17
nrows=17


plt.figure(figsize=(ncol,5*ncol))
for i in range(1,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# there are outliers present in R(runs), ERA(earned runs average), SHO (shutouts), and SV (saves) Error (E)

# %%
#checking outliers using zscore

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df.shape, df_new.shape
# Out:
# ((30, 17), (29, 17))

# %% [markdown]
# here only one record is removed as outlier in new column so no need of removing it as we already have less data with us

# %% [markdown]
# ### checking skewness

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
#visualizing skewness
for i in df.columns:
    plt.figure()
    sns.distplot(df[i])

# %% [markdown]
# No data is right skewed or left skewed , but there is a high disperion in the data, i.e., data is widely spread from the mean

# %% [markdown]
# ### separating Target and Independent values

# %%
x=df.iloc[:,1:]
x.head()
# Out:
#      R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  SV  \
# 0  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8  56
# 1  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12  45
# 2  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10  38
# 3  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9  37
# 4  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12  35
#
#      E
# 0   88
# 1   86
# 2   79
# 3  101
# 4   86

# %% [markdown]
# as the all columns are in integer format only ERA is in float so converting it into float for better learning of model

# %%
x['ERA'] = x['ERA'].astype('int64')

# %%
y=df.iloc[:,0]

# %% [markdown]
# ### selecting the best random state

# %%
#importing necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
bestrandomstate=0
maxr2score=0
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    predlr=lr.predict(x_test)
    r2score=r2_score(y_test,predlr)
    if r2score > maxr2score:
        maxr2score = r2score
        bestrandomstate=i
print(f"best r2_score is {maxr2score} at random_state of {bestrandomstate}")
# Out:
# best r2_score is 0.9565952867225398 at random_state of 506

# %% [markdown]
# ###### we got max r2_Score  of 95.65 % at random_state of 506

# %%
#using best random state for the model LinearRegression

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=506)
lr=LinearRegression()
lr.fit(x_train,y_train)
predlr=lr.predict(x_test)
print(r2_score(y_test,predlr))
# Out:
# 0.9565952867225398

# %% [markdown]
# ### Cross Validation of the Model

# %%
from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cvs=cross_val_score(lr,x,y,cv=j)
    cvsmean=cvs.mean()
    print(f"At cross fold {j} the cv_score is {cvsmean} ")
    print("\n")
# Out:
# At cross fold 2 the cv_score is -1.1835215922191478
#
#
# At cross fold 3 the cv_score is 0.13592224679863515
#
#
# At cross fold 4 the cv_score is 0.40520330913389124
#
#
# At cross fold 5 the cv_score is -0.34440505748126055
#
#
# At cross fold 6 the cv_score is 0.1960967514664543
#
#
# At cross fold 7 the cv_score is 0.46157863414832156
#
#
# At cross fold 8 the cv_score is 0.300879333518933
#
#
# At cross fold 9 the cv_score is -4.285820856955973

# %% [markdown]
# since at the fold of 7 the cross val score is highest i.e., 46.15%

# %% [markdown]
# here we have solved the problem of Overfitting and UnderFitting by checking through cross_val_score

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=predlr,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel("Actual_Wins",fontsize=14)
plt.ylabel("predicted_Wins",fontsize=20)
plt.title("Linear_Regression",fontsize=25)
plt.show()

# %% [markdown]
# As our model is 46 percent accurate that's why the points are very near to the best fit line

# %% [markdown]
# ### Regularization

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
parameters={'alpha':[.0001,.001,.01,.1,1,10], 'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters,cv=7)
clf.fit(x_train,y_train)


print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
ls=Lasso(alpha=10,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)

pred_ls = ls.predict(x_test)

lss=r2_score(y_test,pred_ls)
lss
# Out:
# 0.7946457779074159

# %%
cv_score=cross_val_score(ls,x,y,cv=7)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.46931601165974873

# %% [markdown]
# at Lasso we are getting cvscore of 46.93  and r2score as 79.464

# %% [markdown]
# ### Ensemble Techniques

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters={'criterion':['mse','mae'],'max_features':["auto","sqrt",'log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'auto'}

# %%
rf=RandomForestRegressor(criterion='mae' ,max_features='auto')
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_rf=rf.predict(x_test)

rfs= r2_score(y_test,pred_rf)
print("R2_score",rfs*100)
# Out:
# R2_score 24.9682803418804

# %%
cv_score=cross_val_score(rf,x,y,cv=7)
cv_mean=cv_score.mean()
cv_mean
# Out:
# -0.03454511464539018

# %% [markdown]
#
# 1)  Linear Regression  is having r2_score  95   and cross_val_score  of   45  so the Difference is    50
#
# 2)  Lasso  is having r2_score 79  and cross_val_score  of     46  so the Difference is    33
#
# 3)  RandomForestRegressor is having r2_score 24  and cross_val_score  of  -0.30  so the Difference is  24

# %% [markdown]
# ## conclusion

# %% [markdown]
# ###### from above we can conclude that Lasso is giving best accuracy and good cross_val_score as compared to LinearRegression and RandomForestRegressor

# %% [markdown]
# ### Saving the Model

# %%
import pickle
filename='baseball.pkl'
pickle.dump(ls,open(filename,'wb'))

# %% [markdown]
# #cross-checking that how well our model has learnt

# %%
loaded_model=pickle.load(open('baseball.pkl','rb'))
result=loaded_model.score(x_test,y_test)

print(result)
# Out:
# 0.7946457779074159

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],pred_ls[:]],index=["Predicted","Original"])

# %%
conclusion
# Out:
#                    0          1          2          3          4          5  \
# Predicted  96.049055  81.777025  84.702379  76.686393  70.941357  85.032372
# Original   96.049055  81.777025  84.702379  76.686393  70.941357  85.032372
#
#                    6
# Predicted  66.953463
# Original   66.953463
